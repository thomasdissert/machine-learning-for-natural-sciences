# %% [markdown]
# # Exercise Sheet No. 10
#
# ---
#
# Machine Learning for Natural Sciences, Summer 2021, Jun.-Prof. Pascal Friederich, pascal.friederich@kit.edu
#
# Deadline: 04.07.2022, 8 am
#
# Tutor: andre.eberhard@kit.edu
#
# **Please ask questions in the forum and only contact the Tutor when there are issues with the grading**
#
# ---
# **Topic**: This exercise sheet will introduce you to machine learning on graphs.

# %% [markdown]
# # Graph Theory
# From [wikipedia](https://en.wikipedia.org/wiki/Graph_theory): "In mathematics, graph theory is the study of graphs, which are mathematical structures used to model pairwise relations between objects. A graph in this context is made up of vertices (also called nodes or points) which are connected by edges (also called links or lines). A distinction is made between undirected graphs, where edges link two vertices symmetrically, and directed graphs, where edges link two vertices asymmetrically. Graphs are one of the principal objects of study in discrete mathematics."
#
# In one restricted but very common sense of the term, a graph is an ordered pair $G = ( V , E )$ comprising:
#
# * The vertex set $V$ of vertices (also called nodes or points);
# * The edge set $E\subseteq \{ \{x, y\} \mid x, y \in V \}$ edges (also called links or lines), which are unordered pairs of vertices (that is, an edge is associated with two distinct vertices).
#
# To avoid ambiguity, this type of object may be called precisely an undirected simple graph.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Example of a graph
G = nx.krackhardt_kite_graph()
nx.draw(G, pos=nx.kamada_kawai_layout(G))

# %% [markdown]
# # Graph convolutional neural networks (GCN)
#
# Graph convolutional neural networks are a natural extension of CNNs for graph-structured data. A simple but efficient Graph Neural Network was introduced in ["Semi-Supervised Classification with Graph Convolutional Networks"](https://arxiv.org/abs/1609.02907) by Kipf et al. (2016). Below is a description of the model and its applications taken are from https://tkipf.github.io/graph-convolutional-networks/. We will implement this model and test it on some graph data.
#
# ### GCNs Part I: Definitions
#
# Currently, most graph neural network models have a somewhat universal architecture in common. We will refer to these models as Graph Convolutional Networks (GCNs); convolutional, because filter parameters are typically shared over all locations in the graph (or a subset thereof as in [Duvenaud et al., NIPS 2015](https://proceedings.neurips.cc/paper/2015/hash/f9be311e65d81a9ad8150a60844bb94c-Abstract.html)).
#
# For these models, the goal is then to learn a function of signals/features on a graph $G = (V, E)$ which takes as input:
#
# * A feature description $x_i$ for every node $i$; summarized in a $N\times D$ feature matrix $X$ ($N$: number of nodes, $D$: number of input features)
# * A representative description of the graph structure in matrix form; typically in the form of an [adjacency matrix](https://en.wikipedia.org/wiki/Adjacency_matrix) $A$ (or some function thereof)
#
# and produces a node-level output $Z$ (an $N\times F$ feature matrix, where $F$ is the number of output features per node). Graph-level outputs can be modeled by introducing some form of pooling operation (see, e.g. [Duvenaud et al., NIPS 2015](https://proceedings.neurips.cc/paper/2015/hash/f9be311e65d81a9ad8150a60844bb94c-Abstract.html)).
#
# Every neural network layer can then be written as a non-linear function
#
# $$H^{(l+1)}=f(H^{(l)}, A),$$
#
# with $H^{(0)}=X$ and $H^{(L)}=Z$ (or $z$ for graph-level outputs), $L$ being the number of layers. The specific models then differ only in how $f(⋅,⋅)$ is chosen and parameterized.
#
# ### GCNs Part II: A simple example
#
# As an example, let's consider the following very simple form of a layer-wise propagation rule:
#
# $$f(H^{(l)},A)= \sigma (AH^{(l)}W^{(l)}),$$
#
# where $W^{(l)}$ is a weight matrix for the $l$-th neural network layer and $\sigma(⋅)$ is a non-linear activation function like the ReLU. Despite its simplicity this model is already quite powerful (we'll come to that in a moment).
#
# But first, let us address two limitations of this simple model: multiplication with $A$ means that, for every node, we sum up all the feature vectors of all neighboring nodes but not the node itself (unless there are self-loops in the graph). We can "fix" this by enforcing self-loops in the graph: we simply add the identity matrix to $A$.
#
# The second major limitation is that $A$ is typically not normalized and therefore the multiplication with $A$ will completely change the scale of the feature vectors proportional to a node's degree. Normalizing $A$ such that all rows sum to one, i.e. $D^{−1}A$, where $D$ is the diagonal node degree matrix, gets rid of this problem. Multiplying with $D^{−1}A$ now corresponds to taking the average of neighboring node features. In practice, dynamics get more interesting when we use a symmetric normalization, i.e. $D^{−\frac{1}{2}} A D^{−\frac{1}{2}}$ (as this no longer amounts to mere averaging of neighboring nodes). Combining these two tricks, we essentially arrive at the propagation rule introduced in [Kipf & Welling](https://arxiv.org/abs/1609.02907) (ICLR 2017):
#
# $$f(H^{(l)},A)=\sigma \, ( \hat{D}^{−\frac{1}{2}} \hat{A} \hat{D}^{−\frac{1}{2}} H^{(l)}W^{(l)}),$$
#
# with $\hat{A}=A+I$, where $I$ is the identity matrix and $\hat{D}$ is the diagonal node degree matrix of $\hat{A}$.

# %% [markdown]
# For a better understanding, let us additionally build the connection between Message Passing Networks and Graph (Convolutional) Networks.
# In the message passing framework, for each node $v$, on each iteration $t$ we construct messages
# $$m_{v}^{t+1} = \sum_{w \in N(v)} M_{t}(h_{v}^{t},h_{w}^{t},e_{vw})$$
# and updates of a node's hidden state
# $$h_{v}^{t+1} = U(h_{v}^{t}, m_{v}^{t+1})$$
#
# with $h_{v}^{0}$ being the initial features of node $v$.
# While the matrix formulation may seem unrelated to the message passing framework at first sight, it is in fact one particular instance of message passing.
#
# Let $G = (V, E)$ be a graph and $n = |V|$. Let $A \in \mathbb{R}^{n \times n}$ be the graph's adjacency matrix induced by $E$. Let $X \in \mathbb{R}^{n \times D}$ be the node feature tensor. We use the slice notation as in Python, numpy, TensorFlow or PyTorch, i.e., $A_{0:}$ indexes the first row of $A$ which indicates
# whether node $0$ is connected to nodes $0 .. n$.
#
# The dot product $A_{0:}X$ then effectively performs two steps. First, during the multiplication step of the dot product, the $0-1$ entries of the row act as a (convolutional) filter on the node feature tensor $X$ by pointwise products, i.e., they define $N(v)$. Second, during the addition step of the dot product, $\sum_{w \in N(v)}$ is calculated. Since we do not perform any additional steps during message construction, our message function is simply $M_{t}(h_{v}^{t},h_{w}^{t},e_{vw}) = h_{w}^{t}.$
#
# Similarly, as we do not have any further operations to perform via matrix multiplication, our update function is thus $h_{v}^{t+1} = U(h_{v}^{t}, m_{v}^{t+1})= m_{v}^{t+1}$.
#
# Therefore, $AX$ effectively performs a full graph convolution step via matrix multiplication. As a result, the modification (like normalizing it) of $A$ results in a different filter and in turn yields a different node and graph representation. This vectorized implementation is especially efficient for dense graphs. For large sparse graphs, sparse matrix multiplication or edge lists are preferred due to the large number of multiplications by 0.

# %% [markdown]
# Next, we will take a closer look at how this type of model operates on a very simple example graph: Zachary's karate club network (make sure to check out the [Wikipedia article](https://en.wikipedia.org/wiki/Zachary%27s_karate_club)!). A social network of a karate club was studied by Wayne W. Zachary for a period of three years from 1970 to 1972. The network captures 34 members of a karate club, documenting links between pairs of members who interacted outside the club. During the study a conflict arose between the administrator "John A" and instructor "Mr. Hi" (pseudonyms), which led to the split of the club into two. Half of the members formed a new club around Mr. Hi; members from the other part found a new instructor or gave up karate. Based on collected data Zachary correctly assigned all but one member of the club to the groups they actually joined after the split.

# %%
G = nx.karate_club_graph()
labels = [G.nodes()[i]["club"] for i in range(nx.number_of_nodes(G))]
print("Example of labels[5:15] :", labels[5:15])
labels_onehot = [0 if x == "Mr. Hi" else 1 for x in labels]
labels_color = ["green" if x == "Mr. Hi" else "red" for x in labels]
nx.draw_circular(G, with_labels=True, node_color=labels_color)
plt.show()
# Out:
# Example of labels[5:15] : ['Mr. Hi', 'Mr. Hi', 'Mr. Hi', 'Mr. Hi', 'Officer', 'Mr. Hi', 'Mr. Hi', 'Mr. Hi', 'Mr. Hi', 'Officer']

# %%
import scipy
import scipy.sparse as sp
import numpy as np

# Adjacency matrix as sparse matrix
A = nx.adjacency_matrix(G)
print(A.toarray())
# Out:
# [[0 4 5 ... 2 0 0]
#  [4 0 6 ... 0 0 0]
#  [5 6 0 ... 0 2 0]
#  ...
#  [2 0 0 ... 0 4 4]
#  [0 0 2 ... 4 0 5]
#  [0 0 0 ... 4 5 0]]
# C:\Users\THOMAS~1\AppData\Local\Temp/ipykernel_11044/3568717484.py:6: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   A = nx.adjacency_matrix(G)

# %% [markdown]
# ### 10.1 Normalized adjacency matrix
# Compute the normalized adjacency matrix $A_{norm} = \hat{D}^{−\frac{1}{2}} \hat{A} \hat{D}^{−\frac{1}{2}}$, with $\hat{A}=A+I$, where $I$ is the identity matrix and $\hat{D}$ is the diagonal node degree matrix of $\hat{A}$.
# You have to implement ``compute_normalized_adj`` using scipy's sparse matrix functions, such as `.sum`, `sp.diag`, `sp.eye`, `.shape`, `.transpose` and `.dot`. It is okay to compute the power of the row- and column sum with `numpy`. You may have to check for `np.inf` here when taking $\hat{D}^{−\frac{1}{2}}$.

# %%
def compute_normalized_adj(adj):
    """Compute scaled adjacency matrix D^-0.5*(A + I)*D^-0.5
    with the degree matrix D of (A+I).
    
    Args:
        adj (scipy.sparse): Sparse matrix representation of A with shape (N, N)
    
    Returns:
        sp.sparse.coo_matrix: Sparse matrix representation of D^-0.5*(A + I)*D^-0.5
    """
    # YOUR CODE HERE
    A_ = adj + np.identity(adj.shape[0])
    D_ = np.eye(adj.shape[0])
    np.fill_diagonal(D_, np.sum(A_, axis=1))
    
    D_sqrt = np.power(D_, -0.5)
    
    D_sqrt[np.isinf(D_sqrt)] = 0
    
    a_norm = sp.coo.coo_matrix(D_sqrt @ A_ @ D_sqrt)
    
    return a_norm

# %%
# test on the Karate Club network
A_norm = compute_normalized_adj(A)
# Out:
# C:\Users\THOMAS~1\AppData\Local\Temp/ipykernel_11044/2896118177.py:16: RuntimeWarning: divide by zero encountered in power
#   D_sqrt = np.power(D_, -0.5)
# C:\Users\THOMAS~1\AppData\Local\Temp/ipykernel_11044/2896118177.py:20: DeprecationWarning: Please use `coo_matrix` from the `scipy.sparse` namespace, the `scipy.sparse.coo` namespace is deprecated.
#   a_norm = sp.coo.coo_matrix(D_sqrt @ A_ @ D_sqrt)

# %%
assert isinstance(A_norm, scipy.sparse.coo_matrix)

test_arr_1 = np.array([
    [0.023256, 0.111369, 0.130766, 0.104957, 0.152499],
    [0.111369, 0.033333, 0.187867, 0.125656, 0.000000],
    [0.130766, 0.187867, 0.029412, 0.118033, 0.000000],
    [0.104957, 0.125656, 0.118033, 0.052632, 0.000000],
    [0.152499, 0.000000, 0.000000, 0.000000, 0.111111]
])

assert np.abs(A_norm.tocoo().toarray()[:5, :5] - test_arr_1).max() < 1e-4, "absolute difference too large"

# %% [markdown]
# Now we implement a TensorFlow model, which accepts the node features and the normalized adjacency matrix as inputs. The actual convolution realized by a (sparse) matrix multiplication is given in the layer below: `GCNConvolution`. This means the scaling does not to be performed within the model but can be done beforehand via `compute_normalized_adj`.

# %%
import tensorflow as tf


class GCNConvolution(tf.keras.layers.Layer):

    def __init__(self, **kwargs):
        super(GCNConvolution, self).__init__(**kwargs)

    def call(self, inputs, **kwargs):
        adj, x = inputs
        return tf.sparse.sparse_dense_matmul(adj, x)

# %% [markdown]
# We set up the model in the functional API for TensorFlow Keras. You can read about this here: https://www.tensorflow.org/guide/keras/functional. A skeleton of the intended model is shown below. You have to add 3 layers of convolution. For the weights $W^{(l)}$ you can simply use `tf.keras.layers.Dense` with `linear` activation and without any `use_bias=False` and for the non-linearity after the matrix multiplication you can use `tf.keras.layers.Activation`. As activation, you can use ``"relu"`` and the dimension of the kernel is given already below as `hidden_dim`. We wrote some pseudo-code in the section, where you have to implement the model-part.

# %%
# Model properties
hidden_dim = 34
target_dim = 2
depth = 3
# Model definition
input_feat = tf.keras.layers.Input(shape=(34,), name="node_input", dtype="float32")  # Node features
input_adj = tf.keras.layers.Input(shape=(34,), name="adj_input", dtype="float32", sparse=True)  # Scaled Adjacency matrix

x = input_feat
for i in range(depth):
    # Pseudo-Code of the model "x = D^-0.5*(A + I)*D^-0.5 * W *x"
    #
    # x = W*x (via tf.keras.layers.Dense(hidden_dim))
    # x = A_scaled * x (via GCNConvolution())
    # x = sigma(x) (via tf.keras.layers.Activation("relu"))
    #

    # YOUR CODE HERE
    x = tf.keras.layers.Dense(hidden_dim, activation="linear", use_bias=False)(x)
    x = GCNConvolution()((input_adj, x))
    x = tf.keras.layers.Activation('relu')(x)

out_classes = tf.keras.layers.Dense(target_dim, activation="softmax")(x)
model = tf.keras.models.Model(inputs=[input_adj, input_feat], outputs=out_classes)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  node_input (InputLayer)        [(None, 34)]         0           []
#
#  adj_input (InputLayer)         [(None, 34)]         0           []
#
#  dense_8 (Dense)                (None, 34)           1156        ['node_input[0][0]']
#
#  gcn_convolution_3 (GCNConvolut  (None, 34)          0           ['adj_input[0][0]',
#  ion)                                                             'dense_8[0][0]']
#
#  activation_6 (Activation)      (None, 34)           0           ['gcn_convolution_3[0][0]']
#
#  dense_9 (Dense)                (None, 34)           1156        ['activation_6[0][0]']
#
#  gcn_convolution_4 (GCNConvolut  (None, 34)          0           ['adj_input[0][0]',
#  ion)                                                             'dense_9[0][0]']
#
#  activation_7 (Activation)      (None, 34)           0           ['gcn_convolution_4[0][0]']
#
#  dense_10 (Dense)               (None, 34)           1156        ['activation_7[0][0]']
#
#  gcn_convolution_5 (GCNConvolut  (None, 34)          0           ['adj_input[0][0]',
#  ion)                                                             'dense_10[0][0]']
#
#  activation_8 (Activation)      (None, 34)           0           ['gcn_convolution_5[0][0]']
#
#  dense_11 (Dense)               (None, 2)            70          ['activation_8[0][0]']
#
# ==================================================================================================
# Total params: 3,538
# Trainable params: 3,538
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# We will train the model above on a semi-supervised learning procedure, meaning that we will train the model on the Karate club network with a couple of nodes cloaked or covered and then test if the network can predict the right assignment of the unknown students. Since the network does not have features `X`, we will simply assume `X=I`. Check the code below.

# %%
from sklearn.model_selection import train_test_split

# Features and labels
X = np.eye(34)
Y = np.array([[1, 0] if x == "Mr. Hi" else [0, 1] for x in labels])
As = A_norm.tocsr().sorted_indices().tocoo()
# Train validation mask to cover nodes in the training
index_karate = np.arange(34)
ind_train, ind_val = train_test_split(index_karate, test_size=0.25, random_state=42)
val_mask = np.zeros_like(index_karate)
train_mask = np.zeros_like(index_karate)
val_mask[ind_val] = 1
train_mask[ind_train] = 1
#Draw the graphs
plt.figure(figsize=(15, 5))
plt.subplot(121)
nx.draw_circular(G, with_labels=True, node_color=[x if train_mask[i] == 1 else "black" for i, x in enumerate(labels_color)])
plt.title("Training Graph")
plt.subplot(122)
nx.draw_circular(G, with_labels=True, node_color=[x if val_mask[i] == 1 else "black" for i, x in enumerate(labels_color)])
plt.title("Validation Graph")
plt.show()

# %% [markdown]
# We can use TensorFlow Keras API to train the model with some modifications. This is a somewhat hacky solution and not really as the Keras training API is intended. We directly insert the sparse matrix and Keras will think of the nodes as samples. We therefore have to fix the `batch_size=34`. Also we must prevent shuffling of the nodes (that will destroy our graph) and set `shuffle=False`. The covering of validation node labels can be realized with a `sample_weight=train_mask` that sets the validation nodes to zero in the loss (since nodes correspond to samples in this case).

# %%
# Compile model with optimizer and loss
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(
    loss="categorical_crossentropy",
    optimizer=optimizer,
    weighted_metrics=["categorical_accuracy"]
)

hist = model.fit(
    x=[As, X], y=Y,
    epochs=100,
    batch_size=34,
    verbose=1,
    shuffle=False,  # Since we do not really have batches, nodes must not be shuffled
    sample_weight=train_mask  # Important to hide values from
)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 319ms/step - loss: 0.5090 - categorical_accuracy: 0.6400
# Epoch 2/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5074 - categorical_accuracy: 0.8400
# Epoch 3/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5058 - categorical_accuracy: 0.8400
# Epoch 4/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5043 - categorical_accuracy: 0.8000
# Epoch 5/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5028 - categorical_accuracy: 0.8000
# Epoch 6/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5014 - categorical_accuracy: 0.8000
# Epoch 7/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4999 - categorical_accuracy: 0.7600
# Epoch 8/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4984 - categorical_accuracy: 0.7600
# Epoch 9/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4969 - categorical_accuracy: 0.7600
# Epoch 10/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4953 - categorical_accuracy: 0.7600
# Epoch 11/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4937 - categorical_accuracy: 0.7600
# Epoch 12/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4920 - categorical_accuracy: 0.7600
# Epoch 13/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4903 - categorical_accuracy: 0.7600
# Epoch 14/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4886 - categorical_accuracy: 0.8400
# Epoch 15/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4868 - categorical_accuracy: 0.8400
# Epoch 16/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4849 - categorical_accuracy: 0.8400
# Epoch 17/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4830 - categorical_accuracy: 0.8400
# Epoch 18/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4809 - categorical_accuracy: 0.8400
# Epoch 19/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4788 - categorical_accuracy: 0.8400
# Epoch 20/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4766 - categorical_accuracy: 0.8400
# Epoch 21/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4742 - categorical_accuracy: 0.8400
# Epoch 22/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4718 - categorical_accuracy: 0.8400
# Epoch 23/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4692 - categorical_accuracy: 0.8800
# Epoch 24/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4666 - categorical_accuracy: 0.8800
# Epoch 25/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4638 - categorical_accuracy: 0.8800
# Epoch 26/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4609 - categorical_accuracy: 0.8800
# Epoch 27/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4579 - categorical_accuracy: 0.8800
# Epoch 28/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4547 - categorical_accuracy: 0.8800
# Epoch 29/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4513 - categorical_accuracy: 0.8800
# Epoch 30/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4478 - categorical_accuracy: 0.8800
# Epoch 31/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4440 - categorical_accuracy: 0.8800
# Epoch 32/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4401 - categorical_accuracy: 0.8800
# Epoch 33/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4360 - categorical_accuracy: 0.8800
# Epoch 34/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4317 - categorical_accuracy: 0.9200
# Epoch 35/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4271 - categorical_accuracy: 0.9600
# Epoch 36/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4224 - categorical_accuracy: 0.9600
# Epoch 37/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4174 - categorical_accuracy: 0.9600
# Epoch 38/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4122 - categorical_accuracy: 0.9600
# Epoch 39/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4069 - categorical_accuracy: 1.0000
# Epoch 40/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4013 - categorical_accuracy: 1.0000
# Epoch 41/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3955 - categorical_accuracy: 1.0000
# Epoch 42/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3895 - categorical_accuracy: 1.0000
# Epoch 43/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3834 - categorical_accuracy: 1.0000
# Epoch 44/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3770 - categorical_accuracy: 1.0000
# Epoch 45/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3704 - categorical_accuracy: 1.0000
# Epoch 46/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3636 - categorical_accuracy: 1.0000
# Epoch 47/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3566 - categorical_accuracy: 1.0000
# Epoch 48/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3495 - categorical_accuracy: 1.0000
# Epoch 49/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3421 - categorical_accuracy: 1.0000
# Epoch 50/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3346 - categorical_accuracy: 1.0000
# Epoch 51/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3270 - categorical_accuracy: 1.0000
# Epoch 52/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3193 - categorical_accuracy: 1.0000
# Epoch 53/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3114 - categorical_accuracy: 1.0000
# Epoch 54/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3034 - categorical_accuracy: 1.0000
# Epoch 55/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2954 - categorical_accuracy: 1.0000
# Epoch 56/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2872 - categorical_accuracy: 1.0000
# Epoch 57/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2790 - categorical_accuracy: 1.0000
# Epoch 58/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2709 - categorical_accuracy: 1.0000
# Epoch 59/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2627 - categorical_accuracy: 1.0000
# Epoch 60/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2545 - categorical_accuracy: 1.0000
# Epoch 61/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2463 - categorical_accuracy: 1.0000
# Epoch 62/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2383 - categorical_accuracy: 1.0000
# Epoch 63/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2303 - categorical_accuracy: 1.0000
# Epoch 64/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2223 - categorical_accuracy: 1.0000
# Epoch 65/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2145 - categorical_accuracy: 1.0000
# Epoch 66/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2068 - categorical_accuracy: 1.0000
# Epoch 67/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1993 - categorical_accuracy: 1.0000
# Epoch 68/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1918 - categorical_accuracy: 1.0000
# Epoch 69/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1846 - categorical_accuracy: 1.0000
# Epoch 70/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1775 - categorical_accuracy: 1.0000
# Epoch 71/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1707 - categorical_accuracy: 1.0000
# Epoch 72/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1640 - categorical_accuracy: 1.0000
# Epoch 73/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1574 - categorical_accuracy: 1.0000
# Epoch 74/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1510 - categorical_accuracy: 1.0000
# Epoch 75/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1448 - categorical_accuracy: 1.0000
# Epoch 76/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1387 - categorical_accuracy: 1.0000
# Epoch 77/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1328 - categorical_accuracy: 1.0000
# Epoch 78/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1271 - categorical_accuracy: 1.0000
# Epoch 79/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1216 - categorical_accuracy: 1.0000
# Epoch 80/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1163 - categorical_accuracy: 1.0000
# Epoch 81/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1111 - categorical_accuracy: 1.0000
# Epoch 82/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1061 - categorical_accuracy: 1.0000
# Epoch 83/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1012 - categorical_accuracy: 1.0000
# Epoch 84/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0966 - categorical_accuracy: 1.0000
# Epoch 85/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0921 - categorical_accuracy: 1.0000
# Epoch 86/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0879 - categorical_accuracy: 1.0000
# Epoch 87/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0838 - categorical_accuracy: 1.0000
# Epoch 88/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0799 - categorical_accuracy: 1.0000
# Epoch 89/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0762 - categorical_accuracy: 1.0000
# Epoch 90/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0726 - categorical_accuracy: 1.0000
# Epoch 91/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0692 - categorical_accuracy: 1.0000
# Epoch 92/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0660 - categorical_accuracy: 1.0000
# Epoch 93/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0629 - categorical_accuracy: 1.0000
# Epoch 94/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0599 - categorical_accuracy: 1.0000
# Epoch 95/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0571 - categorical_accuracy: 1.0000
# Epoch 96/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0544 - categorical_accuracy: 1.0000
# Epoch 97/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0519 - categorical_accuracy: 1.0000
# Epoch 98/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0495 - categorical_accuracy: 1.0000
# Epoch 99/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0472 - categorical_accuracy: 1.0000
# Epoch 100/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0450 - categorical_accuracy: 1.0000

# %%
val_loss = model.evaluate([As, X], Y, batch_size=34, sample_weight=val_mask)
# Out:
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0592 - categorical_accuracy: 0.8889

# %%
pred = model.predict([As, X], batch_size=34)
pred_val = pred[np.array(val_mask, dtype="bool")]
pred_train = pred[np.array(train_mask, dtype="bool")]
plt.figure(figsize=(15, 5))
plt.subplot(121)
plt.scatter(pred_train[:, 0], pred_train[:, 1], s=100, alpha=0.5,
            c=[x for i, x in enumerate(labels_color) if train_mask[i] == 1])
plt.plot((0, 1), c="black")
plt.title("Training Prediction")
plt.subplot(122)
plt.scatter(pred_val[:, 0], pred_val[:, 1], s=100, alpha=0.5, c=[x for i, x in enumerate(labels_color) if val_mask[i] == 1])
plt.title("Validation Prediction")
plt.plot((0, 1), c="black")
plt.show()

# %%
assert val_loss[-1] > 0.8
assert hist.history["categorical_accuracy"][-1] > 0.95

# %% [markdown]
# Why is it not surprising that the training accuracy approaches 1.0 ? But why is it interesting that the validation accuracy is high?

# %%
answer_training_acc = None
answer_validation_acc = None

# YOUR CODE HERE
answer_training_acc = "We are overfitting quite a bit"
answer_validation_acc = "You would not expect, that the validation accuracy is high when the model is overfitting"

# %%
assert isinstance(answer_training_acc, str)
assert isinstance(answer_validation_acc, str)

# %% [markdown]
# # 10.2 Molecules
# Molecules can also be represented as graphs. In this case we have many small(er) graphs and are interested in graph-embedding or graph classification rather than node embedding or classification. For this part we use the MUTAG dataset that classifies a set of small molecules as mutagenes.

# %%
import requests
import zipfile
import os

data_url = "https://ls11-www.cs.tu-dortmund.de/people/morris/graphkerneldatasets/MUTAG.zip"
if not os.path.exists("MUTAG.zip"):
    print("Downloading dataset ...")
    r = requests.get(data_url)
    _ = open("MUTAG.zip", "wb").write(r.content)
    print("Extracting dataset ...")
    archive = zipfile.ZipFile("MUTAG.zip", "r")
    archive.extractall()
    print("Extracting done.")

# %%
def read_mutag_text(filename):
    with open(filename, "r") as f:
        lines = f.read().split("\n")
    indices = [list(map(int, l.split(", "))) for l in lines if l]
    return np.array(indices, dtype="int")

# %%
# Read all mutag files
mutag_A = read_mutag_text("MUTAG/MUTAG_A.txt")
mutag_E = read_mutag_text("MUTAG/MUTAG_edge_labels.txt")
mutag_G = read_mutag_text("MUTAG/MUTAG_graph_indicator.txt")
mutag_N = read_mutag_text("MUTAG/MUTAG_node_labels.txt")
mutag_L = read_mutag_text("MUTAG/MUTAG_graph_labels.txt")

print("Shape of A:", mutag_A.shape)
print("Shape of Edges:", mutag_E.shape)
print("Shape of Graph-ID:", mutag_G.shape)
print("Shape of Nodes:", mutag_N.shape)
print("Shape of Graph-label:", mutag_L.shape)

# Want to start index from zero and not from 1
mutag_A -= 1
mutag_G -= 1
# Out:
# Shape of A: (7442, 2)
# Shape of Edges: (7442, 1)
# Shape of Graph-ID: (3371, 1)
# Shape of Nodes: (3371, 1)
# Shape of Graph-label: (188, 1)

# %%
# Separate the molecular graphs:
atom_code = ["C", "N", "O", "F", "I", "Cl", "Br"]
atom_color_map = {"C": "grey", "N": "green", "O": "blue", "F": "purple", "I": "yellow", "Cl": "pink", "Br": "orange"}
all_graphs = nx.Graph()
for i in range(len(mutag_N)):
    one_hot_atom_embedding = [0] * len(atom_code)  # There are 7 elements in the dataset
    one_hot_atom_embedding[mutag_N[i][0]] = 1
    str_atom_name = atom_code[mutag_N[i][0]]
    all_graphs.add_node(i,
                        features=one_hot_atom_embedding,
                        atom_name=str_atom_name)
for i in range(len(mutag_A)):
    one_hot_bond_embedding = [0] * 4  # There are 3 bond types in the dataset
    one_hot_bond_embedding[mutag_E[i][0]] = 1
    all_graphs.add_edge(mutag_A[i][0], mutag_A[i][1],
                        features=one_hot_bond_embedding)
graphs = []
nodes = np.arange(0, len(mutag_N), 1)
for g in range(0, np.amax(mutag_G)):
    graphs.append(all_graphs.subgraph(nodes[mutag_G[:, 0] == g]).to_directed())

# %%
def plot_sub_graph(gri_plot):
    nx.draw(
        G=graphs[gri_plot],
        pos=nx.kamada_kawai_layout(graphs[gri_plot]),
        labels={n: (graphs[gri_plot].nodes()[n]["atom_name"]) for n in graphs[gri_plot].nodes()},
        node_color=[atom_color_map[graphs[gri_plot].nodes()[n]["atom_name"]] for n in graphs[gri_plot].nodes()]
    )


plt.figure(figsize=(15,12))
plt.subplot(231)
plot_sub_graph(2)
plt.subplot(232)
plot_sub_graph(75)
plt.subplot(233)
plot_sub_graph(23)
plt.subplot(234)
plot_sub_graph(101)
plt.subplot(235)
plot_sub_graph(21)
plt.subplot(236)
plot_sub_graph(123)

# %%
As = [nx.adjacency_matrix(graphs[i]) for i in range(len(graphs))]
Xs = [np.array([g.nodes()[n]["features"] for n in g.nodes()]) for g in graphs]
# Out:
# C:\Users\THOMAS~1\AppData\Local\Temp/ipykernel_11044/1680044078.py:1: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   As = [nx.adjacency_matrix(graphs[i]) for i in range(len(graphs))]

# %%
# Now we scale the matrix and already cast it to a dense array
# If you did not solve previous part you can do it with numpy functions here.
As = [compute_normalized_adj(a).toarray() for a in As]
# Out:
# C:\Users\THOMAS~1\AppData\Local\Temp/ipykernel_11044/2896118177.py:16: RuntimeWarning: divide by zero encountered in power
#   D_sqrt = np.power(D_, -0.5)
# C:\Users\THOMAS~1\AppData\Local\Temp/ipykernel_11044/2896118177.py:20: DeprecationWarning: Please use `coo_matrix` from the `scipy.sparse` namespace, the `scipy.sparse.coo` namespace is deprecated.
#   a_norm = sp.coo.coo_matrix(D_sqrt @ A_ @ D_sqrt)

# %% [markdown]
# To put multiple graphs of different size in a single tensor, we will use padding here. That means we simply fill up the tensor with zeros. However, since zeros can cause non-zero output (e.g. bias), a mask to ignore these values has to be added to the model. Keras also has masking capabilities for example for RNNs/LSTM and Masking passing between layers, but we will do it manually "by hand" or explicitly here.

# %%
A_padded = np.zeros((187, 28, 28))
A_mask = np.zeros((187, 28, 28), dtype="bool")

X_padded = np.zeros((187, 28, 7))
X_mask = np.zeros((187, 28, 1), dtype="bool")

for i, a in enumerate(As):
    # Fill A_padded, A_mask with correct values
    # YOUR CODE HERE
    A_padded[i, :a.shape[0], :a.shape[1]] = a
    A_mask[i, :a.shape[0], :a.shape[1]] = 1

for i, x in enumerate(Xs):
    # Fill X_padded, X_mask with correct values
    # YOUR CODE HERE
    X_padded[i, :x.shape[0], :x.shape[1]] = x
    X_mask[i, :x.shape[0], :x.shape[1]] = 1

labels = mutag_L
labels[labels == -1] = 0  # labels are in {-1, 1}, we want them as {0, 1}

# %%
test_arr_3 = np.array([
    [0.33333333, 0.33333333, 0.00000000, 0.00000000, 0.00000000],
    [0.33333333, 0.33333333, 0.28867513, 0.00000000, 0.00000000],
    [0.00000000, 0.28867513, 0.25000000, 0.25000000, 0.00000000],
    [0.00000000, 0.00000000, 0.25000000, 0.25000000, 0.28867513],
    [0.00000000, 0.00000000, 0.00000000, 0.28867513, 0.33333333]
])

test_arr_4 = np.array([1., 1., 1., 1., 1., 0., 0., 0., 0., 1.])

assert np.abs(A_padded[75, :5, :5] - test_arr_3).max() < 1e-4
assert np.abs(X_padded[75, :10, 0] - test_arr_4).max() < 1e-4

assert np.abs(A_padded[75, 10:, 10:]).max() < 1e-4
assert np.abs(X_padded[75, 10:, :]).max() < 1e-4

# %% [markdown]
# The model can be defined similar to the previous task (skeleton below). However, this time you can do the matrix multiplication with `tf.keras.layers.Dot` and applying the mask with `tf.keras.layers.Multiply`. We will derive a graph-embedding by simply averaging all the node-embeddings of the last layer. For this purpose, we use the `Pooling` layer after the graph convolutions.

# %%
import tensorflow as tf


class Pooling(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(Pooling, self).__init__(**kwargs)

    def call(self, inputs, **kwargs):
        return tf.math.reduce_mean(inputs, axis=1)

# %%
# Model properties
hidden_dim = 32
target_dim = 1
depth = 3

# Model definition
input_adj = tf.keras.layers.Input(shape=(28, 28), name="adj_input", dtype="float32")
input_x = tf.keras.layers.Input(shape=(28, 7), name="atom_input", dtype="float32")
input_x_mask = tf.keras.layers.Input(shape=(28, 1), name="atom_mask", dtype="float32")
x = input_x
for i in range(depth):
    # Pseudo-Code of the model "x = D^-0.5*(A + I)*D^-0.5 * W *x"
    #
    # x = W*x (via tf.keras.layers.Dense(hidden_dim))
    # x = Mask(x) (via tf.keras.layers.Multiply())
    # x = A_scaled * x (via tf.keras.layers.Dot() think about the "axes" argument)
    # x = sigma(x) (via tf.keras.layers.Activation("relu"))
    # x = Mask(x) (via tf.keras.layers.Multiply())
    #
    # YOUR CODE HERE
    x = tf.keras.layers.Dense(hidden_dim, activation="linear", use_bias=False)(x)
    x = tf.keras.layers.Multiply()([x, input_x_mask])
    x = tf.keras.layers.Dot(axes=[-1, 1])([input_adj, x])
    x = tf.keras.layers.Activation('relu')(x)
    x = tf.keras.layers.Multiply()([x, input_x_mask])

x_pool = Pooling()(x)
out_classes = tf.keras.layers.Dense(target_dim, activation="sigmoid")(x_pool)
model = tf.keras.models.Model(inputs=[input_adj, input_x, input_x_mask], outputs=out_classes)
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  atom_input (InputLayer)        [(None, 28, 7)]      0           []
#
#  dense_12 (Dense)               (None, 28, 32)       224         ['atom_input[0][0]']
#
#  atom_mask (InputLayer)         [(None, 28, 1)]      0           []
#
#  adj_input (InputLayer)         [(None, 28, 28)]     0           []
#
#  multiply_6 (Multiply)          (None, 28, 32)       0           ['dense_12[0][0]',
#                                                                   'atom_mask[0][0]']
#
#  dot_3 (Dot)                    (None, 28, 32)       0           ['adj_input[0][0]',
#                                                                   'multiply_6[0][0]']
#
#  activation_9 (Activation)      (None, 28, 32)       0           ['dot_3[0][0]']
#
#  multiply_7 (Multiply)          (None, 28, 32)       0           ['activation_9[0][0]',
#                                                                   'atom_mask[0][0]']
#
#  dense_13 (Dense)               (None, 28, 32)       1024        ['multiply_7[0][0]']
#
#  multiply_8 (Multiply)          (None, 28, 32)       0           ['dense_13[0][0]',
#                                                                   'atom_mask[0][0]']
#
#  dot_4 (Dot)                    (None, 28, 32)       0           ['adj_input[0][0]',
#                                                                   'multiply_8[0][0]']
#
#  activation_10 (Activation)     (None, 28, 32)       0           ['dot_4[0][0]']
#
#  multiply_9 (Multiply)          (None, 28, 32)       0           ['activation_10[0][0]',
#                                                                   'atom_mask[0][0]']
#
#  dense_14 (Dense)               (None, 28, 32)       1024        ['multiply_9[0][0]']
#
#  multiply_10 (Multiply)         (None, 28, 32)       0           ['dense_14[0][0]',
#                                                                   'atom_mask[0][0]']
#
#  dot_5 (Dot)                    (None, 28, 32)       0           ['adj_input[0][0]',
#                                                                   'multiply_10[0][0]']
#
#  activation_11 (Activation)     (None, 28, 32)       0           ['dot_5[0][0]']
#
#  multiply_11 (Multiply)         (None, 28, 32)       0           ['activation_11[0][0]',
#                                                                   'atom_mask[0][0]']
#
#  pooling_1 (Pooling)            (None, 32)           0           ['multiply_11[0][0]']
#
#  dense_15 (Dense)               (None, 1)            33          ['pooling_1[0][0]']
#
# ==================================================================================================
# Total params: 2,305
# Trainable params: 2,305
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Compile model with optimizer and loss
optimizer = tf.keras.optimizers.Adam(lr=1e-3)
model.compile(
    loss="binary_crossentropy",
    optimizer=optimizer,
    weighted_metrics=["accuracy"]
)
hist = model.fit(
    x=[A_padded, X_padded, X_mask],
    y=labels,
    epochs=500,
    batch_size=64,
    verbose=1,
    shuffle=True,
    validation_split=0.15
)
# Out:
# C:\Users\ThomasDissert\miniconda3\envs\aimat\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/500
# 3/3 [==============================] - 1s 65ms/step - loss: 0.6842 - accuracy: 0.6582 - val_loss: 0.6735 - val_accuracy: 0.7241
# Epoch 2/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6767 - accuracy: 0.6582 - val_loss: 0.6645 - val_accuracy: 0.7241
# Epoch 3/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6696 - accuracy: 0.6582 - val_loss: 0.6554 - val_accuracy: 0.7241
# Epoch 4/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6619 - accuracy: 0.6582 - val_loss: 0.6463 - val_accuracy: 0.7241
# Epoch 5/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6538 - accuracy: 0.6582 - val_loss: 0.6371 - val_accuracy: 0.7241
# Epoch 6/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6474 - accuracy: 0.6582 - val_loss: 0.6279 - val_accuracy: 0.7241
# Epoch 7/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6399 - accuracy: 0.6582 - val_loss: 0.6188 - val_accuracy: 0.7241
# Epoch 8/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6321 - accuracy: 0.6582 - val_loss: 0.6097 - val_accuracy: 0.7241
# Epoch 9/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6261 - accuracy: 0.6582 - val_loss: 0.6007 - val_accuracy: 0.7241
# Epoch 10/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6186 - accuracy: 0.6582 - val_loss: 0.5916 - val_accuracy: 0.7241
# Epoch 11/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6115 - accuracy: 0.6582 - val_loss: 0.5824 - val_accuracy: 0.7241
# Epoch 12/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.6051 - accuracy: 0.6582 - val_loss: 0.5734 - val_accuracy: 0.7241
# Epoch 13/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5992 - accuracy: 0.6582 - val_loss: 0.5646 - val_accuracy: 0.7241
# Epoch 14/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5925 - accuracy: 0.6582 - val_loss: 0.5568 - val_accuracy: 0.7241
# Epoch 15/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5878 - accuracy: 0.6582 - val_loss: 0.5496 - val_accuracy: 0.7241
# Epoch 16/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5828 - accuracy: 0.6582 - val_loss: 0.5436 - val_accuracy: 0.7241
# Epoch 17/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5796 - accuracy: 0.6582 - val_loss: 0.5383 - val_accuracy: 0.7241
# Epoch 18/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5765 - accuracy: 0.6582 - val_loss: 0.5343 - val_accuracy: 0.7241
# Epoch 19/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5745 - accuracy: 0.6582 - val_loss: 0.5310 - val_accuracy: 0.7241
# Epoch 20/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5732 - accuracy: 0.6582 - val_loss: 0.5285 - val_accuracy: 0.7241
# Epoch 21/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5718 - accuracy: 0.6582 - val_loss: 0.5267 - val_accuracy: 0.7241
# Epoch 22/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5711 - accuracy: 0.6582 - val_loss: 0.5251 - val_accuracy: 0.7241
# Epoch 23/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5701 - accuracy: 0.6582 - val_loss: 0.5240 - val_accuracy: 0.7241
# Epoch 24/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5695 - accuracy: 0.6582 - val_loss: 0.5231 - val_accuracy: 0.7241
# Epoch 25/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5688 - accuracy: 0.6582 - val_loss: 0.5224 - val_accuracy: 0.7241
# Epoch 26/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5682 - accuracy: 0.6582 - val_loss: 0.5218 - val_accuracy: 0.7241
# Epoch 27/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5674 - accuracy: 0.6582 - val_loss: 0.5209 - val_accuracy: 0.7241
# Epoch 28/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5670 - accuracy: 0.6582 - val_loss: 0.5200 - val_accuracy: 0.7241
# Epoch 29/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5664 - accuracy: 0.6582 - val_loss: 0.5194 - val_accuracy: 0.7241
# Epoch 30/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5657 - accuracy: 0.6582 - val_loss: 0.5193 - val_accuracy: 0.7241
# Epoch 31/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5651 - accuracy: 0.6582 - val_loss: 0.5191 - val_accuracy: 0.7241
# Epoch 32/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5645 - accuracy: 0.6582 - val_loss: 0.5186 - val_accuracy: 0.7241
# Epoch 33/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5638 - accuracy: 0.6582 - val_loss: 0.5176 - val_accuracy: 0.7241
# Epoch 34/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5633 - accuracy: 0.6582 - val_loss: 0.5167 - val_accuracy: 0.7241
# Epoch 35/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5626 - accuracy: 0.6582 - val_loss: 0.5160 - val_accuracy: 0.7241
# Epoch 36/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5620 - accuracy: 0.6582 - val_loss: 0.5153 - val_accuracy: 0.7241
# Epoch 37/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5614 - accuracy: 0.6582 - val_loss: 0.5146 - val_accuracy: 0.7241
# Epoch 38/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5608 - accuracy: 0.6582 - val_loss: 0.5138 - val_accuracy: 0.7241
# Epoch 39/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5602 - accuracy: 0.6582 - val_loss: 0.5133 - val_accuracy: 0.7241
# Epoch 40/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5596 - accuracy: 0.6582 - val_loss: 0.5124 - val_accuracy: 0.7241
# Epoch 41/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5591 - accuracy: 0.6582 - val_loss: 0.5121 - val_accuracy: 0.7241
# Epoch 42/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5583 - accuracy: 0.6582 - val_loss: 0.5111 - val_accuracy: 0.7241
# Epoch 43/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5575 - accuracy: 0.6582 - val_loss: 0.5107 - val_accuracy: 0.7241
# Epoch 44/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5569 - accuracy: 0.6582 - val_loss: 0.5102 - val_accuracy: 0.7241
# Epoch 45/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5561 - accuracy: 0.6582 - val_loss: 0.5102 - val_accuracy: 0.7241
# Epoch 46/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5554 - accuracy: 0.6582 - val_loss: 0.5100 - val_accuracy: 0.7241
# Epoch 47/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5546 - accuracy: 0.6582 - val_loss: 0.5097 - val_accuracy: 0.7241
# Epoch 48/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5539 - accuracy: 0.6582 - val_loss: 0.5097 - val_accuracy: 0.7241
# Epoch 49/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5532 - accuracy: 0.6582 - val_loss: 0.5097 - val_accuracy: 0.7241
# Epoch 50/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5525 - accuracy: 0.6582 - val_loss: 0.5092 - val_accuracy: 0.7241
# Epoch 51/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5518 - accuracy: 0.6582 - val_loss: 0.5085 - val_accuracy: 0.7241
# Epoch 52/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5509 - accuracy: 0.6582 - val_loss: 0.5083 - val_accuracy: 0.7241
# Epoch 53/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5501 - accuracy: 0.6582 - val_loss: 0.5076 - val_accuracy: 0.7241
# Epoch 54/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5493 - accuracy: 0.6582 - val_loss: 0.5067 - val_accuracy: 0.7241
# Epoch 55/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5486 - accuracy: 0.6582 - val_loss: 0.5062 - val_accuracy: 0.7241
# Epoch 56/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5475 - accuracy: 0.6582 - val_loss: 0.5054 - val_accuracy: 0.7241
# Epoch 57/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5468 - accuracy: 0.6582 - val_loss: 0.5040 - val_accuracy: 0.7241
# Epoch 58/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5456 - accuracy: 0.6582 - val_loss: 0.5033 - val_accuracy: 0.7241
# Epoch 59/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5446 - accuracy: 0.6582 - val_loss: 0.5023 - val_accuracy: 0.7241
# Epoch 60/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5435 - accuracy: 0.6582 - val_loss: 0.5010 - val_accuracy: 0.7241
# Epoch 61/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5425 - accuracy: 0.6582 - val_loss: 0.5000 - val_accuracy: 0.7241
# Epoch 62/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5417 - accuracy: 0.6582 - val_loss: 0.4995 - val_accuracy: 0.7241
# Epoch 63/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5403 - accuracy: 0.6582 - val_loss: 0.4980 - val_accuracy: 0.7241
# Epoch 64/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5398 - accuracy: 0.6582 - val_loss: 0.4963 - val_accuracy: 0.7241
# Epoch 65/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5383 - accuracy: 0.6582 - val_loss: 0.4957 - val_accuracy: 0.7241
# Epoch 66/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5377 - accuracy: 0.6582 - val_loss: 0.4952 - val_accuracy: 0.7241
# Epoch 67/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5363 - accuracy: 0.6582 - val_loss: 0.4934 - val_accuracy: 0.7241
# Epoch 68/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5352 - accuracy: 0.6582 - val_loss: 0.4923 - val_accuracy: 0.7241
# Epoch 69/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5338 - accuracy: 0.6582 - val_loss: 0.4910 - val_accuracy: 0.7241
# Epoch 70/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5329 - accuracy: 0.6582 - val_loss: 0.4901 - val_accuracy: 0.7241
# Epoch 71/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5316 - accuracy: 0.6582 - val_loss: 0.4892 - val_accuracy: 0.7241
# Epoch 72/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5305 - accuracy: 0.6582 - val_loss: 0.4877 - val_accuracy: 0.7241
# Epoch 73/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5292 - accuracy: 0.6582 - val_loss: 0.4852 - val_accuracy: 0.7241
# Epoch 74/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5290 - accuracy: 0.6582 - val_loss: 0.4831 - val_accuracy: 0.7241
# Epoch 75/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.5271 - accuracy: 0.6582 - val_loss: 0.4831 - val_accuracy: 0.7241
# Epoch 76/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5258 - accuracy: 0.6582 - val_loss: 0.4850 - val_accuracy: 0.7241
# Epoch 77/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5247 - accuracy: 0.6646 - val_loss: 0.4858 - val_accuracy: 0.7241
# Epoch 78/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5238 - accuracy: 0.6646 - val_loss: 0.4853 - val_accuracy: 0.7241
# Epoch 79/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5228 - accuracy: 0.6646 - val_loss: 0.4843 - val_accuracy: 0.7241
# Epoch 80/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5219 - accuracy: 0.6646 - val_loss: 0.4803 - val_accuracy: 0.7241
# Epoch 81/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5200 - accuracy: 0.6646 - val_loss: 0.4779 - val_accuracy: 0.7241
# Epoch 82/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5187 - accuracy: 0.6646 - val_loss: 0.4764 - val_accuracy: 0.7241
# Epoch 83/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5178 - accuracy: 0.6646 - val_loss: 0.4770 - val_accuracy: 0.7241
# Epoch 84/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5160 - accuracy: 0.6646 - val_loss: 0.4760 - val_accuracy: 0.7241
# Epoch 85/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5147 - accuracy: 0.6646 - val_loss: 0.4743 - val_accuracy: 0.7241
# Epoch 86/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5136 - accuracy: 0.6646 - val_loss: 0.4723 - val_accuracy: 0.7241
# Epoch 87/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5123 - accuracy: 0.6646 - val_loss: 0.4710 - val_accuracy: 0.7241
# Epoch 88/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5109 - accuracy: 0.6646 - val_loss: 0.4688 - val_accuracy: 0.7241
# Epoch 89/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5101 - accuracy: 0.6646 - val_loss: 0.4667 - val_accuracy: 0.7241
# Epoch 90/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5089 - accuracy: 0.6646 - val_loss: 0.4663 - val_accuracy: 0.7586
# Epoch 91/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5079 - accuracy: 0.6709 - val_loss: 0.4652 - val_accuracy: 0.7586
# Epoch 92/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5064 - accuracy: 0.6709 - val_loss: 0.4675 - val_accuracy: 0.7586
# Epoch 93/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5049 - accuracy: 0.6962 - val_loss: 0.4696 - val_accuracy: 0.7586
# Epoch 94/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5042 - accuracy: 0.7152 - val_loss: 0.4716 - val_accuracy: 0.7931
# Epoch 95/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5038 - accuracy: 0.7278 - val_loss: 0.4725 - val_accuracy: 0.7931
# Epoch 96/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5030 - accuracy: 0.7405 - val_loss: 0.4702 - val_accuracy: 0.7931
# Epoch 97/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5017 - accuracy: 0.7405 - val_loss: 0.4651 - val_accuracy: 0.7931
# Epoch 98/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.5008 - accuracy: 0.7278 - val_loss: 0.4610 - val_accuracy: 0.7931
# Epoch 99/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4996 - accuracy: 0.7215 - val_loss: 0.4597 - val_accuracy: 0.7931
# Epoch 100/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4986 - accuracy: 0.7278 - val_loss: 0.4605 - val_accuracy: 0.7931
# Epoch 101/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4977 - accuracy: 0.7405 - val_loss: 0.4648 - val_accuracy: 0.7931
# Epoch 102/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4967 - accuracy: 0.7468 - val_loss: 0.4669 - val_accuracy: 0.8276
# Epoch 103/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4973 - accuracy: 0.7468 - val_loss: 0.4684 - val_accuracy: 0.8276
# Epoch 104/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4954 - accuracy: 0.7532 - val_loss: 0.4628 - val_accuracy: 0.8276
# Epoch 105/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4958 - accuracy: 0.7468 - val_loss: 0.4562 - val_accuracy: 0.7931
# Epoch 106/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4940 - accuracy: 0.7468 - val_loss: 0.4555 - val_accuracy: 0.7931
# Epoch 107/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4934 - accuracy: 0.7468 - val_loss: 0.4569 - val_accuracy: 0.8276
# Epoch 108/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4922 - accuracy: 0.7532 - val_loss: 0.4600 - val_accuracy: 0.8276
# Epoch 109/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4918 - accuracy: 0.7658 - val_loss: 0.4623 - val_accuracy: 0.7931
# Epoch 110/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4916 - accuracy: 0.7595 - val_loss: 0.4623 - val_accuracy: 0.7931
# Epoch 111/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4908 - accuracy: 0.7595 - val_loss: 0.4595 - val_accuracy: 0.7931
# Epoch 112/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4903 - accuracy: 0.7595 - val_loss: 0.4563 - val_accuracy: 0.7931
# Epoch 113/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4895 - accuracy: 0.7722 - val_loss: 0.4549 - val_accuracy: 0.7931
# Epoch 114/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4892 - accuracy: 0.7658 - val_loss: 0.4552 - val_accuracy: 0.7931
# Epoch 115/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4885 - accuracy: 0.7595 - val_loss: 0.4584 - val_accuracy: 0.7586
# Epoch 116/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4883 - accuracy: 0.7532 - val_loss: 0.4590 - val_accuracy: 0.7586
# Epoch 117/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4884 - accuracy: 0.7658 - val_loss: 0.4554 - val_accuracy: 0.7586
# Epoch 118/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4875 - accuracy: 0.7658 - val_loss: 0.4555 - val_accuracy: 0.7586
# Epoch 119/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4865 - accuracy: 0.7532 - val_loss: 0.4588 - val_accuracy: 0.7586
# Epoch 120/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4863 - accuracy: 0.7405 - val_loss: 0.4635 - val_accuracy: 0.7241
# Epoch 121/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4869 - accuracy: 0.7405 - val_loss: 0.4651 - val_accuracy: 0.7241
# Epoch 122/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4862 - accuracy: 0.7405 - val_loss: 0.4605 - val_accuracy: 0.7241
# Epoch 123/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4852 - accuracy: 0.7405 - val_loss: 0.4552 - val_accuracy: 0.7586
# Epoch 124/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4850 - accuracy: 0.7532 - val_loss: 0.4523 - val_accuracy: 0.7586
# Epoch 125/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4847 - accuracy: 0.7532 - val_loss: 0.4524 - val_accuracy: 0.7586
# Epoch 126/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4844 - accuracy: 0.7405 - val_loss: 0.4541 - val_accuracy: 0.7586
# Epoch 127/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4836 - accuracy: 0.7405 - val_loss: 0.4548 - val_accuracy: 0.7586
# Epoch 128/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4831 - accuracy: 0.7405 - val_loss: 0.4565 - val_accuracy: 0.7241
# Epoch 129/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4835 - accuracy: 0.7405 - val_loss: 0.4594 - val_accuracy: 0.7241
# Epoch 130/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4826 - accuracy: 0.7405 - val_loss: 0.4570 - val_accuracy: 0.7241
# Epoch 131/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4825 - accuracy: 0.7405 - val_loss: 0.4535 - val_accuracy: 0.7241
# Epoch 132/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4823 - accuracy: 0.7405 - val_loss: 0.4541 - val_accuracy: 0.7241
# Epoch 133/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4816 - accuracy: 0.7405 - val_loss: 0.4535 - val_accuracy: 0.7241
# Epoch 134/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4821 - accuracy: 0.7405 - val_loss: 0.4532 - val_accuracy: 0.7241
# Epoch 135/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4811 - accuracy: 0.7405 - val_loss: 0.4489 - val_accuracy: 0.7586
# Epoch 136/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4817 - accuracy: 0.7468 - val_loss: 0.4481 - val_accuracy: 0.7586
# Epoch 137/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4816 - accuracy: 0.7468 - val_loss: 0.4508 - val_accuracy: 0.7241
# Epoch 138/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4806 - accuracy: 0.7405 - val_loss: 0.4551 - val_accuracy: 0.7241
# Epoch 139/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4804 - accuracy: 0.7468 - val_loss: 0.4594 - val_accuracy: 0.7241
# Epoch 140/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4799 - accuracy: 0.7532 - val_loss: 0.4599 - val_accuracy: 0.6897
# Epoch 141/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4796 - accuracy: 0.7532 - val_loss: 0.4594 - val_accuracy: 0.6897
# Epoch 142/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4792 - accuracy: 0.7532 - val_loss: 0.4601 - val_accuracy: 0.6897
# Epoch 143/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4792 - accuracy: 0.7595 - val_loss: 0.4618 - val_accuracy: 0.6897
# Epoch 144/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4792 - accuracy: 0.7658 - val_loss: 0.4585 - val_accuracy: 0.7241
# Epoch 145/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4784 - accuracy: 0.7532 - val_loss: 0.4580 - val_accuracy: 0.7241
# Epoch 146/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4780 - accuracy: 0.7532 - val_loss: 0.4569 - val_accuracy: 0.7241
# Epoch 147/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4776 - accuracy: 0.7532 - val_loss: 0.4583 - val_accuracy: 0.7241
# Epoch 148/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4782 - accuracy: 0.7532 - val_loss: 0.4585 - val_accuracy: 0.6897
# Epoch 149/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4771 - accuracy: 0.7595 - val_loss: 0.4646 - val_accuracy: 0.6897
# Epoch 150/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4779 - accuracy: 0.7595 - val_loss: 0.4669 - val_accuracy: 0.6897
# Epoch 151/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4780 - accuracy: 0.7595 - val_loss: 0.4711 - val_accuracy: 0.7241
# Epoch 152/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4783 - accuracy: 0.7595 - val_loss: 0.4694 - val_accuracy: 0.6897
# Epoch 153/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4774 - accuracy: 0.7595 - val_loss: 0.4654 - val_accuracy: 0.6552
# Epoch 154/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4763 - accuracy: 0.7595 - val_loss: 0.4575 - val_accuracy: 0.7241
# Epoch 155/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4751 - accuracy: 0.7595 - val_loss: 0.4531 - val_accuracy: 0.7241
# Epoch 156/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4752 - accuracy: 0.7532 - val_loss: 0.4504 - val_accuracy: 0.7241
# Epoch 157/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4754 - accuracy: 0.7595 - val_loss: 0.4498 - val_accuracy: 0.7241
# Epoch 158/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4752 - accuracy: 0.7595 - val_loss: 0.4506 - val_accuracy: 0.7241
# Epoch 159/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4747 - accuracy: 0.7595 - val_loss: 0.4514 - val_accuracy: 0.7241
# Epoch 160/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4739 - accuracy: 0.7595 - val_loss: 0.4550 - val_accuracy: 0.7241
# Epoch 161/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4740 - accuracy: 0.7595 - val_loss: 0.4596 - val_accuracy: 0.7241
# Epoch 162/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4737 - accuracy: 0.7595 - val_loss: 0.4594 - val_accuracy: 0.7241
# Epoch 163/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4730 - accuracy: 0.7595 - val_loss: 0.4557 - val_accuracy: 0.7241
# Epoch 164/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4729 - accuracy: 0.7595 - val_loss: 0.4500 - val_accuracy: 0.7241
# Epoch 165/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4731 - accuracy: 0.7595 - val_loss: 0.4483 - val_accuracy: 0.7241
# Epoch 166/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4731 - accuracy: 0.7595 - val_loss: 0.4504 - val_accuracy: 0.7241
# Epoch 167/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4713 - accuracy: 0.7658 - val_loss: 0.4580 - val_accuracy: 0.7241
# Epoch 168/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4716 - accuracy: 0.7595 - val_loss: 0.4659 - val_accuracy: 0.7241
# Epoch 169/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4731 - accuracy: 0.7658 - val_loss: 0.4684 - val_accuracy: 0.7586
# Epoch 170/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4724 - accuracy: 0.7722 - val_loss: 0.4616 - val_accuracy: 0.7241
# Epoch 171/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4705 - accuracy: 0.7595 - val_loss: 0.4537 - val_accuracy: 0.7241
# Epoch 172/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4714 - accuracy: 0.7595 - val_loss: 0.4462 - val_accuracy: 0.7241
# Epoch 173/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4714 - accuracy: 0.7595 - val_loss: 0.4452 - val_accuracy: 0.7241
# Epoch 174/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4717 - accuracy: 0.7595 - val_loss: 0.4474 - val_accuracy: 0.7241
# Epoch 175/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4702 - accuracy: 0.7595 - val_loss: 0.4501 - val_accuracy: 0.7241
# Epoch 176/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4692 - accuracy: 0.7595 - val_loss: 0.4549 - val_accuracy: 0.7241
# Epoch 177/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4690 - accuracy: 0.7658 - val_loss: 0.4596 - val_accuracy: 0.7241
# Epoch 178/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4689 - accuracy: 0.7595 - val_loss: 0.4597 - val_accuracy: 0.7241
# Epoch 179/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4690 - accuracy: 0.7595 - val_loss: 0.4563 - val_accuracy: 0.7241
# Epoch 180/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4684 - accuracy: 0.7658 - val_loss: 0.4508 - val_accuracy: 0.7241
# Epoch 181/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4682 - accuracy: 0.7658 - val_loss: 0.4503 - val_accuracy: 0.7241
# Epoch 182/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4677 - accuracy: 0.7595 - val_loss: 0.4498 - val_accuracy: 0.7241
# Epoch 183/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4677 - accuracy: 0.7595 - val_loss: 0.4523 - val_accuracy: 0.7241
# Epoch 184/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4668 - accuracy: 0.7658 - val_loss: 0.4553 - val_accuracy: 0.7241
# Epoch 185/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4664 - accuracy: 0.7658 - val_loss: 0.4595 - val_accuracy: 0.7586
# Epoch 186/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4669 - accuracy: 0.7658 - val_loss: 0.4629 - val_accuracy: 0.7586
# Epoch 187/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4668 - accuracy: 0.7595 - val_loss: 0.4632 - val_accuracy: 0.7586
# Epoch 188/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4662 - accuracy: 0.7595 - val_loss: 0.4594 - val_accuracy: 0.7586
# Epoch 189/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4652 - accuracy: 0.7722 - val_loss: 0.4532 - val_accuracy: 0.7241
# Epoch 190/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4662 - accuracy: 0.7595 - val_loss: 0.4497 - val_accuracy: 0.7241
# Epoch 191/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4660 - accuracy: 0.7658 - val_loss: 0.4522 - val_accuracy: 0.7241
# Epoch 192/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4654 - accuracy: 0.7658 - val_loss: 0.4517 - val_accuracy: 0.7241
# Epoch 193/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4645 - accuracy: 0.7658 - val_loss: 0.4482 - val_accuracy: 0.6897
# Epoch 194/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4659 - accuracy: 0.7595 - val_loss: 0.4466 - val_accuracy: 0.6897
# Epoch 195/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4643 - accuracy: 0.7595 - val_loss: 0.4516 - val_accuracy: 0.7241
# Epoch 196/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4642 - accuracy: 0.7658 - val_loss: 0.4571 - val_accuracy: 0.7586
# Epoch 197/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4631 - accuracy: 0.7722 - val_loss: 0.4568 - val_accuracy: 0.7586
# Epoch 198/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4629 - accuracy: 0.7722 - val_loss: 0.4564 - val_accuracy: 0.7586
# Epoch 199/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4625 - accuracy: 0.7722 - val_loss: 0.4563 - val_accuracy: 0.7586
# Epoch 200/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4623 - accuracy: 0.7722 - val_loss: 0.4540 - val_accuracy: 0.7586
# Epoch 201/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4619 - accuracy: 0.7722 - val_loss: 0.4537 - val_accuracy: 0.7586
# Epoch 202/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4628 - accuracy: 0.7722 - val_loss: 0.4522 - val_accuracy: 0.6897
# Epoch 203/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4612 - accuracy: 0.7658 - val_loss: 0.4561 - val_accuracy: 0.7586
# Epoch 204/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4622 - accuracy: 0.7595 - val_loss: 0.4581 - val_accuracy: 0.7586
# Epoch 205/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4616 - accuracy: 0.7722 - val_loss: 0.4513 - val_accuracy: 0.6897
# Epoch 206/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4607 - accuracy: 0.7658 - val_loss: 0.4503 - val_accuracy: 0.6897
# Epoch 207/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4604 - accuracy: 0.7658 - val_loss: 0.4518 - val_accuracy: 0.7241
# Epoch 208/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4596 - accuracy: 0.7658 - val_loss: 0.4583 - val_accuracy: 0.7241
# Epoch 209/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4599 - accuracy: 0.7595 - val_loss: 0.4609 - val_accuracy: 0.6897
# Epoch 210/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4595 - accuracy: 0.7595 - val_loss: 0.4572 - val_accuracy: 0.7241
# Epoch 211/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4586 - accuracy: 0.7595 - val_loss: 0.4522 - val_accuracy: 0.7241
# Epoch 212/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4591 - accuracy: 0.7785 - val_loss: 0.4471 - val_accuracy: 0.6897
# Epoch 213/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4588 - accuracy: 0.7785 - val_loss: 0.4478 - val_accuracy: 0.6897
# Epoch 214/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4599 - accuracy: 0.7722 - val_loss: 0.4529 - val_accuracy: 0.7241
# Epoch 215/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4579 - accuracy: 0.7595 - val_loss: 0.4517 - val_accuracy: 0.7241
# Epoch 216/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4570 - accuracy: 0.7785 - val_loss: 0.4478 - val_accuracy: 0.6897
# Epoch 217/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4575 - accuracy: 0.7785 - val_loss: 0.4452 - val_accuracy: 0.6897
# Epoch 218/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4582 - accuracy: 0.7785 - val_loss: 0.4453 - val_accuracy: 0.6897
# Epoch 219/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4573 - accuracy: 0.7785 - val_loss: 0.4488 - val_accuracy: 0.7241
# Epoch 220/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4570 - accuracy: 0.7658 - val_loss: 0.4570 - val_accuracy: 0.6897
# Epoch 221/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4560 - accuracy: 0.7595 - val_loss: 0.4581 - val_accuracy: 0.6897
# Epoch 222/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4558 - accuracy: 0.7595 - val_loss: 0.4584 - val_accuracy: 0.6897
# Epoch 223/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4554 - accuracy: 0.7595 - val_loss: 0.4580 - val_accuracy: 0.6897
# Epoch 224/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4553 - accuracy: 0.7658 - val_loss: 0.4560 - val_accuracy: 0.6897
# Epoch 225/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4549 - accuracy: 0.7722 - val_loss: 0.4544 - val_accuracy: 0.6897
# Epoch 226/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4542 - accuracy: 0.7722 - val_loss: 0.4528 - val_accuracy: 0.6897
# Epoch 227/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4549 - accuracy: 0.7722 - val_loss: 0.4506 - val_accuracy: 0.7241
# Epoch 228/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4537 - accuracy: 0.7722 - val_loss: 0.4527 - val_accuracy: 0.6897
# Epoch 229/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4536 - accuracy: 0.7722 - val_loss: 0.4566 - val_accuracy: 0.6897
# Epoch 230/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4532 - accuracy: 0.7722 - val_loss: 0.4563 - val_accuracy: 0.6897
# Epoch 231/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4528 - accuracy: 0.7722 - val_loss: 0.4550 - val_accuracy: 0.6897
# Epoch 232/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4525 - accuracy: 0.7722 - val_loss: 0.4527 - val_accuracy: 0.6897
# Epoch 233/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4530 - accuracy: 0.7722 - val_loss: 0.4517 - val_accuracy: 0.6897
# Epoch 234/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4515 - accuracy: 0.7722 - val_loss: 0.4567 - val_accuracy: 0.6897
# Epoch 235/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4516 - accuracy: 0.7722 - val_loss: 0.4613 - val_accuracy: 0.6897
# Epoch 236/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4526 - accuracy: 0.7595 - val_loss: 0.4631 - val_accuracy: 0.6897
# Epoch 237/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4517 - accuracy: 0.7722 - val_loss: 0.4565 - val_accuracy: 0.6897
# Epoch 238/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4502 - accuracy: 0.7722 - val_loss: 0.4477 - val_accuracy: 0.6897
# Epoch 239/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4513 - accuracy: 0.7722 - val_loss: 0.4422 - val_accuracy: 0.6897
# Epoch 240/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4519 - accuracy: 0.7722 - val_loss: 0.4440 - val_accuracy: 0.7241
# Epoch 241/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4505 - accuracy: 0.7722 - val_loss: 0.4496 - val_accuracy: 0.6897
# Epoch 242/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4501 - accuracy: 0.7722 - val_loss: 0.4553 - val_accuracy: 0.6897
# Epoch 243/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4498 - accuracy: 0.7722 - val_loss: 0.4543 - val_accuracy: 0.6897
# Epoch 244/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4514 - accuracy: 0.7722 - val_loss: 0.4468 - val_accuracy: 0.6897
# Epoch 245/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4494 - accuracy: 0.7722 - val_loss: 0.4520 - val_accuracy: 0.6897
# Epoch 246/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4483 - accuracy: 0.7722 - val_loss: 0.4543 - val_accuracy: 0.6897
# Epoch 247/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4489 - accuracy: 0.7722 - val_loss: 0.4564 - val_accuracy: 0.6897
# Epoch 248/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4485 - accuracy: 0.7722 - val_loss: 0.4599 - val_accuracy: 0.6897
# Epoch 249/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4485 - accuracy: 0.7722 - val_loss: 0.4579 - val_accuracy: 0.6897
# Epoch 250/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4472 - accuracy: 0.7722 - val_loss: 0.4522 - val_accuracy: 0.6897
# Epoch 251/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4466 - accuracy: 0.7722 - val_loss: 0.4470 - val_accuracy: 0.6897
# Epoch 252/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4475 - accuracy: 0.7722 - val_loss: 0.4448 - val_accuracy: 0.6897
# Epoch 253/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4480 - accuracy: 0.7722 - val_loss: 0.4425 - val_accuracy: 0.6897
# Epoch 254/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4487 - accuracy: 0.7658 - val_loss: 0.4422 - val_accuracy: 0.6897
# Epoch 255/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4482 - accuracy: 0.7722 - val_loss: 0.4467 - val_accuracy: 0.6897
# Epoch 256/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4473 - accuracy: 0.7722 - val_loss: 0.4535 - val_accuracy: 0.6897
# Epoch 257/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4455 - accuracy: 0.7722 - val_loss: 0.4542 - val_accuracy: 0.6897
# Epoch 258/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4454 - accuracy: 0.7722 - val_loss: 0.4546 - val_accuracy: 0.6897
# Epoch 259/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4452 - accuracy: 0.7722 - val_loss: 0.4548 - val_accuracy: 0.6897
# Epoch 260/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4452 - accuracy: 0.7722 - val_loss: 0.4510 - val_accuracy: 0.6897
# Epoch 261/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4454 - accuracy: 0.7722 - val_loss: 0.4461 - val_accuracy: 0.6897
# Epoch 262/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4461 - accuracy: 0.7722 - val_loss: 0.4468 - val_accuracy: 0.6897
# Epoch 263/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4462 - accuracy: 0.7722 - val_loss: 0.4562 - val_accuracy: 0.6897
# Epoch 264/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4439 - accuracy: 0.7722 - val_loss: 0.4598 - val_accuracy: 0.6897
# Epoch 265/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4445 - accuracy: 0.7848 - val_loss: 0.4630 - val_accuracy: 0.6897
# Epoch 266/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4443 - accuracy: 0.7911 - val_loss: 0.4571 - val_accuracy: 0.6897
# Epoch 267/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4430 - accuracy: 0.7722 - val_loss: 0.4511 - val_accuracy: 0.6897
# Epoch 268/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4442 - accuracy: 0.7722 - val_loss: 0.4456 - val_accuracy: 0.6897
# Epoch 269/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4453 - accuracy: 0.7722 - val_loss: 0.4495 - val_accuracy: 0.6897
# Epoch 270/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4442 - accuracy: 0.7722 - val_loss: 0.4528 - val_accuracy: 0.6897
# Epoch 271/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4426 - accuracy: 0.7722 - val_loss: 0.4522 - val_accuracy: 0.6897
# Epoch 272/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4422 - accuracy: 0.7722 - val_loss: 0.4498 - val_accuracy: 0.6897
# Epoch 273/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4430 - accuracy: 0.7722 - val_loss: 0.4492 - val_accuracy: 0.6897
# Epoch 274/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4444 - accuracy: 0.7722 - val_loss: 0.4567 - val_accuracy: 0.6897
# Epoch 275/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4415 - accuracy: 0.7722 - val_loss: 0.4570 - val_accuracy: 0.6897
# Epoch 276/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4414 - accuracy: 0.7722 - val_loss: 0.4558 - val_accuracy: 0.6897
# Epoch 277/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4417 - accuracy: 0.7722 - val_loss: 0.4569 - val_accuracy: 0.6897
# Epoch 278/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4413 - accuracy: 0.7722 - val_loss: 0.4613 - val_accuracy: 0.6897
# Epoch 279/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4424 - accuracy: 0.7975 - val_loss: 0.4640 - val_accuracy: 0.6897
# Epoch 280/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4411 - accuracy: 0.7975 - val_loss: 0.4578 - val_accuracy: 0.6897
# Epoch 281/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4406 - accuracy: 0.7722 - val_loss: 0.4534 - val_accuracy: 0.6897
# Epoch 282/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4415 - accuracy: 0.7722 - val_loss: 0.4541 - val_accuracy: 0.6897
# Epoch 283/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4403 - accuracy: 0.7722 - val_loss: 0.4492 - val_accuracy: 0.6897
# Epoch 284/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4412 - accuracy: 0.7658 - val_loss: 0.4481 - val_accuracy: 0.6897
# Epoch 285/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4413 - accuracy: 0.7658 - val_loss: 0.4483 - val_accuracy: 0.6897
# Epoch 286/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4437 - accuracy: 0.7658 - val_loss: 0.4550 - val_accuracy: 0.6897
# Epoch 287/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4396 - accuracy: 0.7722 - val_loss: 0.4553 - val_accuracy: 0.6897
# Epoch 288/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4400 - accuracy: 0.7722 - val_loss: 0.4529 - val_accuracy: 0.6897
# Epoch 289/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4394 - accuracy: 0.7658 - val_loss: 0.4546 - val_accuracy: 0.6897
# Epoch 290/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4390 - accuracy: 0.7722 - val_loss: 0.4579 - val_accuracy: 0.6897
# Epoch 291/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4386 - accuracy: 0.7785 - val_loss: 0.4601 - val_accuracy: 0.6897
# Epoch 292/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4391 - accuracy: 0.7911 - val_loss: 0.4612 - val_accuracy: 0.6897
# Epoch 293/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4383 - accuracy: 0.7911 - val_loss: 0.4568 - val_accuracy: 0.6897
# Epoch 294/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4394 - accuracy: 0.7722 - val_loss: 0.4565 - val_accuracy: 0.6897
# Epoch 295/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4380 - accuracy: 0.7658 - val_loss: 0.4537 - val_accuracy: 0.6897
# Epoch 296/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4398 - accuracy: 0.7658 - val_loss: 0.4509 - val_accuracy: 0.6897
# Epoch 297/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4399 - accuracy: 0.7658 - val_loss: 0.4533 - val_accuracy: 0.6897
# Epoch 298/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4395 - accuracy: 0.7658 - val_loss: 0.4660 - val_accuracy: 0.6897
# Epoch 299/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4393 - accuracy: 0.7975 - val_loss: 0.4725 - val_accuracy: 0.6897
# Epoch 300/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4385 - accuracy: 0.7975 - val_loss: 0.4646 - val_accuracy: 0.6897
# Epoch 301/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4421 - accuracy: 0.7785 - val_loss: 0.4540 - val_accuracy: 0.6897
# Epoch 302/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4391 - accuracy: 0.7658 - val_loss: 0.4583 - val_accuracy: 0.6897
# Epoch 303/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4351 - accuracy: 0.7848 - val_loss: 0.4778 - val_accuracy: 0.6897
# Epoch 304/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4404 - accuracy: 0.7975 - val_loss: 0.4908 - val_accuracy: 0.7586
# Epoch 305/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4441 - accuracy: 0.8038 - val_loss: 0.4808 - val_accuracy: 0.6897
# Epoch 306/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4402 - accuracy: 0.7975 - val_loss: 0.4651 - val_accuracy: 0.6897
# Epoch 307/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4373 - accuracy: 0.7911 - val_loss: 0.4575 - val_accuracy: 0.6897
# Epoch 308/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4366 - accuracy: 0.7658 - val_loss: 0.4580 - val_accuracy: 0.6897
# Epoch 309/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4364 - accuracy: 0.7658 - val_loss: 0.4574 - val_accuracy: 0.6897
# Epoch 310/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4362 - accuracy: 0.7658 - val_loss: 0.4593 - val_accuracy: 0.6897
# Epoch 311/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4361 - accuracy: 0.7785 - val_loss: 0.4624 - val_accuracy: 0.6897
# Epoch 312/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4364 - accuracy: 0.7911 - val_loss: 0.4653 - val_accuracy: 0.6897
# Epoch 313/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4359 - accuracy: 0.7975 - val_loss: 0.4644 - val_accuracy: 0.6897
# Epoch 314/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4368 - accuracy: 0.7975 - val_loss: 0.4681 - val_accuracy: 0.6897
# Epoch 315/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4354 - accuracy: 0.7975 - val_loss: 0.4654 - val_accuracy: 0.6897
# Epoch 316/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4350 - accuracy: 0.7975 - val_loss: 0.4621 - val_accuracy: 0.6897
# Epoch 317/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4362 - accuracy: 0.7658 - val_loss: 0.4589 - val_accuracy: 0.6897
# Epoch 318/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4359 - accuracy: 0.7785 - val_loss: 0.4638 - val_accuracy: 0.6897
# Epoch 319/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4346 - accuracy: 0.7911 - val_loss: 0.4642 - val_accuracy: 0.6897
# Epoch 320/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4346 - accuracy: 0.7911 - val_loss: 0.4648 - val_accuracy: 0.6897
# Epoch 321/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4350 - accuracy: 0.7911 - val_loss: 0.4680 - val_accuracy: 0.6897
# Epoch 322/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4345 - accuracy: 0.7911 - val_loss: 0.4643 - val_accuracy: 0.6897
# Epoch 323/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4345 - accuracy: 0.7911 - val_loss: 0.4631 - val_accuracy: 0.6897
# Epoch 324/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4343 - accuracy: 0.7785 - val_loss: 0.4587 - val_accuracy: 0.6897
# Epoch 325/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4360 - accuracy: 0.7658 - val_loss: 0.4580 - val_accuracy: 0.6897
# Epoch 326/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4383 - accuracy: 0.7785 - val_loss: 0.4657 - val_accuracy: 0.6897
# Epoch 327/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4338 - accuracy: 0.7911 - val_loss: 0.4628 - val_accuracy: 0.6897
# Epoch 328/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4340 - accuracy: 0.7785 - val_loss: 0.4625 - val_accuracy: 0.6897
# Epoch 329/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4340 - accuracy: 0.7848 - val_loss: 0.4646 - val_accuracy: 0.6897
# Epoch 330/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4343 - accuracy: 0.7911 - val_loss: 0.4654 - val_accuracy: 0.6897
# Epoch 331/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4339 - accuracy: 0.7911 - val_loss: 0.4764 - val_accuracy: 0.6897
# Epoch 332/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4341 - accuracy: 0.7975 - val_loss: 0.4801 - val_accuracy: 0.6897
# Epoch 333/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4348 - accuracy: 0.7975 - val_loss: 0.4771 - val_accuracy: 0.6897
# Epoch 334/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4336 - accuracy: 0.7975 - val_loss: 0.4706 - val_accuracy: 0.6897
# Epoch 335/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4336 - accuracy: 0.7911 - val_loss: 0.4648 - val_accuracy: 0.6897
# Epoch 336/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4339 - accuracy: 0.7911 - val_loss: 0.4684 - val_accuracy: 0.6897
# Epoch 337/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4326 - accuracy: 0.7911 - val_loss: 0.4678 - val_accuracy: 0.6897
# Epoch 338/500
# ...
# Epoch 389/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4288 - accuracy: 0.7911 - val_loss: 0.4758 - val_accuracy: 0.6897
# Epoch 390/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4277 - accuracy: 0.7911 - val_loss: 0.4776 - val_accuracy: 0.6897
# Epoch 391/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4287 - accuracy: 0.7975 - val_loss: 0.4835 - val_accuracy: 0.6897
# Epoch 392/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4283 - accuracy: 0.7975 - val_loss: 0.4822 - val_accuracy: 0.6897
# Epoch 393/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4274 - accuracy: 0.7911 - val_loss: 0.4758 - val_accuracy: 0.6897
# Epoch 394/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4287 - accuracy: 0.7911 - val_loss: 0.4713 - val_accuracy: 0.6897
# Epoch 395/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4274 - accuracy: 0.7911 - val_loss: 0.4750 - val_accuracy: 0.6897
# Epoch 396/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4274 - accuracy: 0.7911 - val_loss: 0.4829 - val_accuracy: 0.6897
# Epoch 397/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4289 - accuracy: 0.7975 - val_loss: 0.4876 - val_accuracy: 0.6897
# Epoch 398/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4284 - accuracy: 0.7911 - val_loss: 0.4777 - val_accuracy: 0.6897
# Epoch 399/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4274 - accuracy: 0.7911 - val_loss: 0.4726 - val_accuracy: 0.6897
# Epoch 400/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4274 - accuracy: 0.7911 - val_loss: 0.4736 - val_accuracy: 0.6897
# Epoch 401/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4268 - accuracy: 0.7911 - val_loss: 0.4751 - val_accuracy: 0.6897
# Epoch 402/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4272 - accuracy: 0.7911 - val_loss: 0.4780 - val_accuracy: 0.6897
# Epoch 403/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4266 - accuracy: 0.7911 - val_loss: 0.4764 - val_accuracy: 0.6897
# Epoch 404/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4261 - accuracy: 0.7911 - val_loss: 0.4722 - val_accuracy: 0.6897
# Epoch 405/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4276 - accuracy: 0.7848 - val_loss: 0.4687 - val_accuracy: 0.6897
# Epoch 406/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4292 - accuracy: 0.7785 - val_loss: 0.4685 - val_accuracy: 0.6897
# Epoch 407/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4291 - accuracy: 0.7722 - val_loss: 0.4677 - val_accuracy: 0.6897
# Epoch 408/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4284 - accuracy: 0.7658 - val_loss: 0.4712 - val_accuracy: 0.6897
# Epoch 409/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4249 - accuracy: 0.7911 - val_loss: 0.4845 - val_accuracy: 0.6897
# Epoch 410/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4255 - accuracy: 0.7848 - val_loss: 0.4978 - val_accuracy: 0.7241
# Epoch 411/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4317 - accuracy: 0.7911 - val_loss: 0.5015 - val_accuracy: 0.7586
# Epoch 412/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4305 - accuracy: 0.7911 - val_loss: 0.4856 - val_accuracy: 0.6897
# Epoch 413/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4257 - accuracy: 0.7911 - val_loss: 0.4751 - val_accuracy: 0.6897
# Epoch 414/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4257 - accuracy: 0.7911 - val_loss: 0.4700 - val_accuracy: 0.6897
# Epoch 415/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4273 - accuracy: 0.7722 - val_loss: 0.4695 - val_accuracy: 0.6897
# Epoch 416/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4271 - accuracy: 0.7911 - val_loss: 0.4725 - val_accuracy: 0.6897
# Epoch 417/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4258 - accuracy: 0.7911 - val_loss: 0.4772 - val_accuracy: 0.6897
# Epoch 418/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4250 - accuracy: 0.7911 - val_loss: 0.4853 - val_accuracy: 0.6897
# Epoch 419/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4268 - accuracy: 0.7911 - val_loss: 0.4912 - val_accuracy: 0.7241
# Epoch 420/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4272 - accuracy: 0.7911 - val_loss: 0.4909 - val_accuracy: 0.7241
# Epoch 421/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4266 - accuracy: 0.7911 - val_loss: 0.4880 - val_accuracy: 0.6897
# Epoch 422/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4270 - accuracy: 0.7975 - val_loss: 0.4800 - val_accuracy: 0.6897
# Epoch 423/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4251 - accuracy: 0.7911 - val_loss: 0.4799 - val_accuracy: 0.6897
# Epoch 424/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4253 - accuracy: 0.7911 - val_loss: 0.4791 - val_accuracy: 0.6897
# Epoch 425/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4250 - accuracy: 0.7911 - val_loss: 0.4759 - val_accuracy: 0.6897
# Epoch 426/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4255 - accuracy: 0.7911 - val_loss: 0.4765 - val_accuracy: 0.6897
# Epoch 427/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4256 - accuracy: 0.7911 - val_loss: 0.4790 - val_accuracy: 0.6897
# Epoch 428/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4250 - accuracy: 0.7911 - val_loss: 0.4786 - val_accuracy: 0.6897
# Epoch 429/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4282 - accuracy: 0.7911 - val_loss: 0.4747 - val_accuracy: 0.6897
# Epoch 430/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4267 - accuracy: 0.7911 - val_loss: 0.4835 - val_accuracy: 0.6897
# Epoch 431/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4249 - accuracy: 0.7911 - val_loss: 0.4866 - val_accuracy: 0.6897
# Epoch 432/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4248 - accuracy: 0.7911 - val_loss: 0.4829 - val_accuracy: 0.6897
# Epoch 433/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4242 - accuracy: 0.7911 - val_loss: 0.4791 - val_accuracy: 0.6897
# Epoch 434/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4241 - accuracy: 0.7911 - val_loss: 0.4757 - val_accuracy: 0.6897
# Epoch 435/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4254 - accuracy: 0.7911 - val_loss: 0.4761 - val_accuracy: 0.6897
# Epoch 436/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4237 - accuracy: 0.7911 - val_loss: 0.4829 - val_accuracy: 0.6897
# Epoch 437/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4237 - accuracy: 0.7975 - val_loss: 0.4930 - val_accuracy: 0.7241
# Epoch 438/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4262 - accuracy: 0.7911 - val_loss: 0.4977 - val_accuracy: 0.7241
# Epoch 439/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4264 - accuracy: 0.7911 - val_loss: 0.4897 - val_accuracy: 0.6897
# Epoch 440/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4250 - accuracy: 0.7975 - val_loss: 0.4797 - val_accuracy: 0.6897
# Epoch 441/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4239 - accuracy: 0.7911 - val_loss: 0.4768 - val_accuracy: 0.6897
# Epoch 442/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4239 - accuracy: 0.7911 - val_loss: 0.4784 - val_accuracy: 0.6897
# Epoch 443/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4240 - accuracy: 0.7911 - val_loss: 0.4814 - val_accuracy: 0.6897
# Epoch 444/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4235 - accuracy: 0.7911 - val_loss: 0.4828 - val_accuracy: 0.6897
# Epoch 445/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4236 - accuracy: 0.7911 - val_loss: 0.4850 - val_accuracy: 0.6897
# Epoch 446/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4239 - accuracy: 0.7911 - val_loss: 0.4832 - val_accuracy: 0.6897
# Epoch 447/500
# 3/3 [==============================] - 0s 14ms/step - loss: 0.4234 - accuracy: 0.7911 - val_loss: 0.4798 - val_accuracy: 0.6897
# Epoch 448/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4242 - accuracy: 0.7911 - val_loss: 0.4732 - val_accuracy: 0.6897
# Epoch 449/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4249 - accuracy: 0.7785 - val_loss: 0.4742 - val_accuracy: 0.6897
# Epoch 450/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4241 - accuracy: 0.7911 - val_loss: 0.4812 - val_accuracy: 0.6897
# Epoch 451/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4229 - accuracy: 0.7911 - val_loss: 0.4884 - val_accuracy: 0.6897
# Epoch 452/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4234 - accuracy: 0.7848 - val_loss: 0.4898 - val_accuracy: 0.6897
# Epoch 453/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4235 - accuracy: 0.7848 - val_loss: 0.4877 - val_accuracy: 0.6897
# Epoch 454/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4230 - accuracy: 0.7848 - val_loss: 0.4866 - val_accuracy: 0.6897
# Epoch 455/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4237 - accuracy: 0.7911 - val_loss: 0.4838 - val_accuracy: 0.6897
# Epoch 456/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4230 - accuracy: 0.7911 - val_loss: 0.4853 - val_accuracy: 0.6897
# Epoch 457/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4229 - accuracy: 0.7848 - val_loss: 0.4908 - val_accuracy: 0.6897
# Epoch 458/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4237 - accuracy: 0.7848 - val_loss: 0.4901 - val_accuracy: 0.6897
# Epoch 459/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4228 - accuracy: 0.7848 - val_loss: 0.4876 - val_accuracy: 0.6897
# Epoch 460/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4224 - accuracy: 0.7911 - val_loss: 0.4820 - val_accuracy: 0.6897
# Epoch 461/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4235 - accuracy: 0.7911 - val_loss: 0.4785 - val_accuracy: 0.6897
# Epoch 462/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4231 - accuracy: 0.7911 - val_loss: 0.4804 - val_accuracy: 0.6897
# Epoch 463/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4224 - accuracy: 0.7911 - val_loss: 0.4840 - val_accuracy: 0.6897
# Epoch 464/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4242 - accuracy: 0.7848 - val_loss: 0.4873 - val_accuracy: 0.6897
# Epoch 465/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4218 - accuracy: 0.7911 - val_loss: 0.4814 - val_accuracy: 0.6897
# Epoch 466/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4234 - accuracy: 0.7911 - val_loss: 0.4785 - val_accuracy: 0.6897
# Epoch 467/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4232 - accuracy: 0.7911 - val_loss: 0.4817 - val_accuracy: 0.6897
# Epoch 468/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4222 - accuracy: 0.7911 - val_loss: 0.4894 - val_accuracy: 0.6897
# Epoch 469/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4223 - accuracy: 0.7848 - val_loss: 0.4938 - val_accuracy: 0.7241
# Epoch 470/500
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4228 - accuracy: 0.7848 - val_loss: 0.4955 - val_accuracy: 0.7241
# Epoch 471/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4227 - accuracy: 0.7848 - val_loss: 0.4919 - val_accuracy: 0.6897
# Epoch 472/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4225 - accuracy: 0.7848 - val_loss: 0.4890 - val_accuracy: 0.6897
# Epoch 473/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4216 - accuracy: 0.7848 - val_loss: 0.4898 - val_accuracy: 0.6897
# Epoch 474/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4214 - accuracy: 0.7848 - val_loss: 0.4881 - val_accuracy: 0.6897
# Epoch 475/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4217 - accuracy: 0.7911 - val_loss: 0.4851 - val_accuracy: 0.6897
# Epoch 476/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4226 - accuracy: 0.7911 - val_loss: 0.4837 - val_accuracy: 0.6897
# Epoch 477/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4217 - accuracy: 0.7911 - val_loss: 0.4911 - val_accuracy: 0.6897
# Epoch 478/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4236 - accuracy: 0.7848 - val_loss: 0.4940 - val_accuracy: 0.6897
# Epoch 479/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4214 - accuracy: 0.7848 - val_loss: 0.4875 - val_accuracy: 0.6897
# Epoch 480/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4211 - accuracy: 0.7911 - val_loss: 0.4856 - val_accuracy: 0.6897
# Epoch 481/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4210 - accuracy: 0.7911 - val_loss: 0.4834 - val_accuracy: 0.6897
# Epoch 482/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4216 - accuracy: 0.7911 - val_loss: 0.4857 - val_accuracy: 0.6897
# Epoch 483/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4213 - accuracy: 0.7911 - val_loss: 0.4890 - val_accuracy: 0.6897
# Epoch 484/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4211 - accuracy: 0.7911 - val_loss: 0.4913 - val_accuracy: 0.6897
# Epoch 485/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4207 - accuracy: 0.7848 - val_loss: 0.4880 - val_accuracy: 0.6897
# Epoch 486/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4234 - accuracy: 0.7911 - val_loss: 0.4831 - val_accuracy: 0.6897
# Epoch 487/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4213 - accuracy: 0.7911 - val_loss: 0.4899 - val_accuracy: 0.6897
# Epoch 488/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4202 - accuracy: 0.7848 - val_loss: 0.4965 - val_accuracy: 0.7241
# Epoch 489/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4214 - accuracy: 0.7911 - val_loss: 0.4987 - val_accuracy: 0.7241
# Epoch 490/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4214 - accuracy: 0.7911 - val_loss: 0.4939 - val_accuracy: 0.6897
# Epoch 491/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4230 - accuracy: 0.7848 - val_loss: 0.4872 - val_accuracy: 0.6897
# Epoch 492/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4208 - accuracy: 0.7911 - val_loss: 0.4913 - val_accuracy: 0.6897
# Epoch 493/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4201 - accuracy: 0.7848 - val_loss: 0.4905 - val_accuracy: 0.6897
# Epoch 494/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4203 - accuracy: 0.7848 - val_loss: 0.4902 - val_accuracy: 0.6897
# Epoch 495/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4212 - accuracy: 0.7911 - val_loss: 0.4874 - val_accuracy: 0.6897
# Epoch 496/500
# 3/3 [==============================] - 0s 13ms/step - loss: 0.4209 - accuracy: 0.7911 - val_loss: 0.4917 - val_accuracy: 0.6897
# Epoch 497/500
# 3/3 [==============================] - 0s 12ms/step - loss: 0.4201 - accuracy: 0.7848 - val_loss: 0.4908 - val_accuracy: 0.6897
# Epoch 498/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4210 - accuracy: 0.7911 - val_loss: 0.4858 - val_accuracy: 0.6897
# Epoch 499/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4204 - accuracy: 0.7911 - val_loss: 0.4858 - val_accuracy: 0.6897
# Epoch 500/500
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4200 - accuracy: 0.7911 - val_loss: 0.4912 - val_accuracy: 0.6897

# %%
def plot_history(hist, validation_freq=1, scale=1):
    plt.figure()
    for key, loss in hist.history.items():
        np_loss = np.array(loss)
        if "val" in key:
            plt.plot(np.arange(np_loss.shape[0]) * validation_freq + validation_freq, np_loss, label=key)
        else:
            plt.plot(np.arange(np_loss.shape[0]), np_loss, label=key)

    plt.xlabel("Epochs")
    plt.ylabel("Loss ")
    plt.title("Loss vs. Epochs")
    plt.legend(loc="upper right", fontsize="x-small")
    plt.show()


plot_history(hist)

# %%
assert hist.history["accuracy"][-1] > 0.7
assert hist.history["val_accuracy"][-1] > 0.5
